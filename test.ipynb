# %% [markdown]
# https://www.kaggle.com/datasets/imtkaggleteam/global-education?select=3-+number-of-out-of-school-children.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("datasets/1- share-of-the-world-population-with-at-least-basic-education.csv")
df1
# Out:
#         Entity      Code  Year  \
# 0      Albania       ALB  2015
# 1      Albania       ALB  2020
# 2      Algeria       DZA  2015
# 3      Algeria       DZA  2020
# 4    Argentina       ARG  2015
# ..         ...       ...   ...
# 463      World  OWID_WRL  2020
# 464     Zambia       ZMB  2015
# 465     Zambia       ZMB  2020
# 466   Zimbabwe       ZWE  2015
# 467   Zimbabwe       ZWE  2020
#
#      Share of population with no formal education, 1820-2020  \
# 0                                                  2.0
# 1                                                  1.0
# 2                                                 16.0
# 3                                                 13.0
# 4                                                  2.0
# ..                                                 ...
# 463                                               13.0
# 464                                                6.0
# 465                                                5.0
# ...

# %%
df2 = pd.read_csv("datasets/2- learning-adjusted-years-of-school-lays.csv")
df2
# Out:
#           Entity Code  Year  Learning-Adjusted Years of School
# 0    Afghanistan  AFG  2017                           4.870000
# 1    Afghanistan  AFG  2018                           4.949788
# 2    Afghanistan  AFG  2020                           5.052838
# 3         Africa  NaN  2017                           4.931378
# 4         Africa  NaN  2018                           5.123904
# ..           ...  ...   ...                                ...
# 632       Zambia  ZMB  2020                           5.036293
# 633     Zimbabwe  ZWE  2010                           6.835774
# 634     Zimbabwe  ZWE  2017                           6.350000
# 635     Zimbabwe  ZWE  2018                           7.006610
# 636     Zimbabwe  ZWE  2020                           7.006610
#
# [637 rows x 4 columns]

# %%
df3 = pd.read_csv("datasets/3- number-of-out-of-school-children.csv")
df3
# Out:
#         Entity Code  Year  \
# 0      Albania  ALB  2000
# 1      Albania  ALB  2001
# 2      Albania  ALB  2013
# 3      Albania  ALB  2014
# 4      Albania  ALB  2015
# ...        ...  ...   ...
# 2575  Zimbabwe  ZWE  2001
# 2576  Zimbabwe  ZWE  2002
# 2577  Zimbabwe  ZWE  2003
# 2578  Zimbabwe  ZWE  2012
# 2579  Zimbabwe  ZWE  2013
#
#       Out-of-school children, adolescents and youth of primary and secondary school age, male (number)  \
# 0                                               78614.0
# 1                                               77837.0
# 2                                               27879.0
# 3                                               21542.0
# 4                                               18407.0
# ...                                                 ...
# 2575                                           386981.0
# 2576                                           462514.0
# 2577                                           522317.0
# ...

# %%
df4 = pd.read_csv("datasets/4- gender-gap-education-levels.csv")
df4
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1986
# 1     Afghanistan  AFG  1990
# 2     Afghanistan  AFG  2003
# 3     Afghanistan  AFG  2004
# 4     Afghanistan  AFG  2009
# ...           ...  ...   ...
# 9223     Zimbabwe  ZWE  2000
# 9224     Zimbabwe  ZWE  2001
# 9225     Zimbabwe  ZWE  2002
# 9226     Zimbabwe  ZWE  2003
# 9227     Zimbabwe  ZWE  1998
#
#       Combined gross enrolment ratio for tertiary education, female  \
# 0                                               0.62182
# 1                                               1.40606
# 2                                               0.51657
# 3                                               0.51396
# 4                                               1.41213
# ...                                                 ...
# 9223                                                NaN
# 9224                                                NaN
# 9225                                                NaN
# ...

# %%
df = df1.set_index('Year').sort_index(ascending=True)
df
# Out:
#                         Entity      Code  \
# Year
# 1820                     World  OWID_WRL
# 1870  Western Offshoots (OECD)       NaN
# 1870     Western Europe (OECD)       NaN
# 1870  Sub-Sahara Africa (OECD)       NaN
# 1870     Eastern Europe (OECD)       NaN
# ...                        ...       ...
# 2020                     Samoa       WSM
# 2020     Sao Tome and Principe       STP
# 2020                   Georgia       GEO
# 2020                   Romania       ROU
# 2020                  Zimbabwe       ZWE
#
#       Share of population with no formal education, 1820-2020  \
# Year
# 1820                                           82.81073
# 1870                                           17.70000
# 1870                                           40.00000
# 1870                                           98.20000
# 1870                                           74.90000
# ...                                                 ...
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Code',
#        'Share of population with no formal education, 1820-2020',
#        'Share of population with some formal education, 1820-2020'],
#       dtype='object')

# %%
df[df.index == 1900]
# Out:
#                                    Entity      Code  \
# Year
# 1900                     East Asia (OECD)       NaN
# 1900                Western Europe (OECD)       NaN
# 1900             Sub-Sahara Africa (OECD)       NaN
# 1900                                World  OWID_WRL
# 1900                Eastern Europe (OECD)       NaN
# 1900  Middle East and North Africa (OECD)       NaN
# 1900             Western Offshoots (OECD)       NaN
# 1900     South and South-East Asia (OECD)       NaN
# 1900   Latin America and Caribbean (OECD)       NaN
#
#       Share of population with no formal education, 1820-2020  \
# Year
# 1900                                               69.8
# 1900                                               19.1
# 1900                                               97.1
# 1900                                               66.8
# 1900                                               66.1
# 1900                                               94.2
# ...

# %%
plt.figure(figsize=(12, 6))

# Plot both metrics
plt.scatter(df.index, df['Share of population with no formal education, 1820-2020'], label='No formal education', alpha=0.6)
plt.scatter(df.index, df['Share of population with some formal education, 1820-2020'], label='Some formal education', alpha=0.6)

# Customize the plot
plt.title('Share of Population by Education Level (1820-2020)')
plt.xlabel('Year')
plt.ylabel('Share of Population (%)')
plt.legend()
plt.grid(True, alpha=0.3)
 
# Show the plot
plt.show()

# %%
df.Entity.unique()
# Out:
# array(['World', 'Western Offshoots (OECD)', 'Western Europe (OECD)',
#        'Sub-Sahara Africa (OECD)', 'Eastern Europe (OECD)',
#        'Middle East and North Africa (OECD)',
#        'South and South-East Asia (OECD)', 'East Asia (OECD)',
#        'Latin America and Caribbean (OECD)', 'Nicaragua', 'New Zealand',
#        'Myanmar', 'Morocco', 'New Caledonia', 'Netherlands', 'Mozambique',
#        'Nepal', 'Namibia', 'Montenegro', 'Mongolia', 'Zimbabwe',
#        'Luxembourg', 'Macao', 'Mali', 'Mexico', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Niger', 'Mauritius', 'Moldova', 'Nigeria',
#        'Albania', 'Norway', 'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syria', 'Tajikistan', 'Tanzania', 'Thailand', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Lithuania', 'Turkey', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Vanuatu', 'Venezuela', 'Vietnam',
# ...

# %%
df[df.Entity == 'World']
# Out:
#      Entity      Code  \
# Year
# 1820  World  OWID_WRL
# 1870  World  OWID_WRL
# 1880  World  OWID_WRL
# 1890  World  OWID_WRL
# 1900  World  OWID_WRL
# 1910  World  OWID_WRL
# 1920  World  OWID_WRL
# 1930  World  OWID_WRL
# 1940  World  OWID_WRL
# 1950  World  OWID_WRL
# 1960  World  OWID_WRL
# 1970  World  OWID_WRL
# 1980  World  OWID_WRL
# 1990  World  OWID_WRL
# 2000  World  OWID_WRL
# 2010  World  OWID_WRL
# 2015  World  OWID_WRL
# 2020  World  OWID_WRL
#
#       Share of population with no formal education, 1820-2020  \
# Year
# 1820                                           82.81073
# 1870                                           76.10000
# 1880                                           73.30000
# 1890                                           70.40000
# 1900                                           66.80000
# 1910                                           64.40000
# 1920                                           61.40000
# ...

# %%
plt.figure(figsize=(12, 6))

# Define regions to filter
regions = ['World', 'Western Offshoots (OECD)', 'Western Europe (OECD)',
           'Sub-Sahara Africa (OECD)', 'Eastern Europe (OECD)',
           'Middle East and North Africa (OECD)', 
           'South and South-East Asia (OECD)', 'East Asia (OECD)',
           'Latin America and Caribbean (OECD)']

# Plot metrics for each region
for region in regions:
    region_data = df[df.Entity == region]
    plt.plot(region_data.index, 
             region_data['Share of population with no formal education, 1820-2020'],
             label=f'No formal education - {region}', alpha=0.8)
    plt.plot(region_data.index,
             region_data['Share of population with some formal education, 1820-2020'], 
             label=f'Some formal education - {region}', alpha=0.8,
             linestyle='--')

# Customize the plot
plt.title('Share of Population by Education Level by Region (1820-2020)')
plt.xlabel('Year')
plt.ylabel('Share of Population (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Show the plot
plt.show()
